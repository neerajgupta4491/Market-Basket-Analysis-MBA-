# %% [raw]
#                                                             NEERAJ GUPTA

# %% [markdown]
# ### Association Rule Mining
#
# Association rule analysis is a technique used in data mining to discover relationships or associations between variables in large datasets. It's most commonly applied in the context of market basket analysis to find out which products tend to be bought together.
# ![image.png](attachment:image.png)
#
# **Market Basket Analysis** - Is a technique used by large retailers to uncover associations between items. It works by looking for combinations of items that occur together frequently in transactions, providing information to understand the purchase behavior. The outcome of this type of technique is, in simple terms, a set of rules that can be understood as “if this, then that”.
#
#
# **Support:** Support is an indication of how frequently the itemset appears in the dataset.
# Support is a so-called frequency constraint. Its main feature is that it possesses the property of down-ward closure which means that all sub sets of a frequent set (support > min. support threshold) are also frequent. This property (actually, the fact that no super set of a infrequent set can be frequent) is used to prune the search space (usually a tree of item sets with increasing size) in level-wise algorithms (e.g., the APRIORI algorithm). The disadvantage of support is the rare item problem. Items that occur very infrequently in the data set are pruned although they would still produce interesting and potentially valuable rules.
#
# **Confidence:** Confidence is an indication of how often the rule has been found to be true.
# Confidence is not down-ward closed and was developed together with support (the so-called support-confidence framework). While support is used to prune the search space and only leave potentially interesting rules, confidence is used in a second step to filter rules that exceed a min. confidence threshold. A problem with confidence is that it is sensitive to the frequency of the consequent (Y) in the data set. Caused by the way confidence is calculated, Ys with higher support will automatically produce higher confidence values even if they exists no association between the items.
#
# **Lift:** The ratio of the observed support to that expected if X and Y were independent.
# Leverage measures the difference of X and Y appearing together in the data set and what would be expected if X and Y where statistically dependent. The rational in a sales setting is to find out how many more units (items X and Y together) are sold than expected from the independent sells. Using min. leverage thresholds at the same time incorporates an implicit frequency constraint. E.g., for setting a min. leverage thresholds to 0.01% (corresponds to 10 occurrence in a data set with 100,000 transactions) one first can use an algorithm to find all itemsets with min. support of 0.01% and then filter the found item sets using the leverage constraint. Because of this property leverage also can suffer from the rare item problem.
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Dell\Downloads\New folder\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\GroceryStoreDataSet.csv",header=None,names=["products"])
df
# Out:
#                           products
# 0               MILK,BREAD,BISCUIT
# 1    BREAD,MILK,BISCUIT,CORNFLAKES
# 2              BREAD,TEA,BOURNVITA
# 3             JAM,MAGGI,BREAD,MILK
# 4                MAGGI,TEA,BISCUIT
# 5              BREAD,TEA,BOURNVITA
# 6             MAGGI,TEA,CORNFLAKES
# 7          MAGGI,BREAD,TEA,BISCUIT
# 8              JAM,MAGGI,BREAD,TEA
# 9                       BREAD,MILK
# 10  COFFEE,COKE,BISCUIT,CORNFLAKES
# 11  COFFEE,COKE,BISCUIT,CORNFLAKES
# 12          COFFEE,SUGER,BOURNVITA
# 13               BREAD,COFFEE,COKE
# 14             BREAD,SUGER,BISCUIT
# 15         COFFEE,SUGER,CORNFLAKES
# 16           BREAD,SUGER,BOURNVITA
# 17              BREAD,COFFEE,SUGER
# 18              BREAD,COFFEE,SUGER
# 19      TEA,MILK,COFFEE,CORNFLAKES

# %%
df.shape
# Out:
# (20, 1)

# %%
df.values
# Out:
# array([['MILK,BREAD,BISCUIT'],
#        ['BREAD,MILK,BISCUIT,CORNFLAKES'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['JAM,MAGGI,BREAD,MILK'],
#        ['MAGGI,TEA,BISCUIT'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['MAGGI,TEA,CORNFLAKES'],
#        ['MAGGI,BREAD,TEA,BISCUIT'],
#        ['JAM,MAGGI,BREAD,TEA'],
#        ['BREAD,MILK'],
#        ['COFFEE,COKE,BISCUIT,CORNFLAKES'],
#        ['COFFEE,COKE,BISCUIT,CORNFLAKES'],
#        ['COFFEE,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,COKE'],
#        ['BREAD,SUGER,BISCUIT'],
#        ['COFFEE,SUGER,CORNFLAKES'],
#        ['BREAD,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,SUGER'],
#        ['BREAD,COFFEE,SUGER'],
#        ['TEA,MILK,COFFEE,CORNFLAKES']], dtype=object)

# %%
data = list(df["products"].apply(lambda x:x.split(',')))
data
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COKE'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\dell\downloads\new folder\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (2.4.2)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\dell\downloads\new folder\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\downloads\new folder\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\downloads\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %%
 #pip install numpy==1.14.5

# %%
pip install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in c:\users\dell\downloads\new folder\lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
np.__version__
# Out:
# '2.4.2'

# %%
data
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COKE'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
#     BISCUIT  BOURNVITA  BREAD  COFFEE   COKE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0      True      False   True   False  False       False  False  False   True
# 1      True      False   True   False  False        True  False  False   True
# 2     False       True   True   False  False       False  False  False  False
# 3     False      False   True   False  False       False   True   True   True
# 4      True      False  False   False  False       False  False   True  False
# 5     False       True   True   False  False       False  False  False  False
# 6     False      False  False   False  False        True  False   True  False
# 7      True      False   True   False  False       False  False   True  False
# 8     False      False   True   False  False       False   True   True  False
# 9     False      False   True   False  False       False  False  False   True
# 10     True      False  False    True   True        True  False  False  False
# 11     True      False  False    True   True        True  False  False  False
# 12    False       True  False    True  False       False  False  False  False
# 13    False      False   True    True   True       False  False  False  False
# 14     True      False   True   False  False       False  False  False  False
# 15    False      False  False    True  False        True  False  False  False
# 16    False       True   True   False  False       False  False  False  False
# 17    False      False   True    True  False       False  False  False  False
# 18    False      False   True    True  False       False  False  False  False
# 19    False      False  False    True  False        True  False  False   True
#
#     SUGER    TEA
# 0   False  False
# 1   False  False
# 2   False   True
# 3   False  False
# 4   False   True
# 5   False   True
# 6   False   True
# 7   False   True
# 8   False   True
# 9   False  False
# 10  False  False
# 11  False  False
# 12   True  False
# 13  False  False
# 14   True  False
# 15   True  False
# 16   True  False
# 17   True  False
# 18   True  False
# 19  False   True

# %%
df.sum().to_frame("Frequency").sort_values("Frequency",ascending=False)
# Out:
#             Frequency
# BREAD              13
# COFFEE              8
# BISCUIT             7
# TEA                 7
# SUGER               6
# CORNFLAKES          6
# MILK                5
# MAGGI               5
# BOURNVITA           4
# COKE                3
# JAM                 2

# %%
import matplotlib.pyplot as plt 

df.sum().to_frame('Frequency').sort_values('Frequency',ascending=False).plot(kind='bar',
                                                                                  figsize=(12,8),
                                                                                  title="Frequent Items")
plt.show()

# %%
df.shape[0]
# Out:
# 20

# %%
# Product Frequency / Total Sales
first = pd.DataFrame(df.sum() / df.shape[0],columns = ["Support"]).sort_values("Support", ascending = False)
first
# Out:
#             Support
# BREAD          0.65
# COFFEE         0.40
# BISCUIT        0.35
# TEA            0.35
# SUGER          0.30
# CORNFLAKES     0.30
# MILK           0.25
# MAGGI          0.25
# BOURNVITA      0.20
# COKE           0.15
# JAM            0.10

# %%
# Elimination by Support Value
first[first.Support < 0.20]
# Out:
#       Support
# COKE     0.15
# JAM      0.10

# %%
import itertools

# %%
second = list(itertools.combinations(first.index, 4))
second = [list(i) for i in second]
# Sample of combinations
second
# Out:
# [['BREAD', 'COFFEE', 'BISCUIT', 'TEA'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'SUGER'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'MILK'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'MAGGI'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'COKE'],
#  ['BREAD', 'COFFEE', 'BISCUIT', 'JAM'],
#  ['BREAD', 'COFFEE', 'TEA', 'SUGER'],
#  ['BREAD', 'COFFEE', 'TEA', 'CORNFLAKES'],
#  ['BREAD', 'COFFEE', 'TEA', 'MILK'],
#  ['BREAD', 'COFFEE', 'TEA', 'MAGGI'],
#  ['BREAD', 'COFFEE', 'TEA', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'TEA', 'COKE'],
#  ['BREAD', 'COFFEE', 'TEA', 'JAM'],
#  ['BREAD', 'COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'COFFEE', 'SUGER', 'MILK'],
#  ['BREAD', 'COFFEE', 'SUGER', 'MAGGI'],
#  ['BREAD', 'COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER', 'COKE'],
#  ['BREAD', 'COFFEE', 'SUGER', 'JAM'],
#  ['BREAD', 'COFFEE', 'CORNFLAKES', 'MILK'],
#  ['BREAD', 'COFFEE', 'CORNFLAKES', 'MAGGI'],
#  ['BREAD', 'COFFEE', 'CORNFLAKES', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'CORNFLAKES', 'COKE'],
#  ['BREAD', 'COFFEE', 'CORNFLAKES', 'JAM'],
#  ['BREAD', 'COFFEE', 'MILK', 'MAGGI'],
#  ['BREAD', 'COFFEE', 'MILK', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'MILK', 'COKE'],
#  ['BREAD', 'COFFEE', 'MILK', 'JAM'],
#  ['BREAD', 'COFFEE', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'MAGGI', 'COKE'],
#  ['BREAD', 'COFFEE', 'MAGGI', 'JAM'],
#  ['BREAD', 'COFFEE', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'COFFEE', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'COFFEE', 'COKE', 'JAM'],
#  ['BREAD', 'BISCUIT', 'TEA', 'SUGER'],
#  ['BREAD', 'BISCUIT', 'TEA', 'CORNFLAKES'],
#  ['BREAD', 'BISCUIT', 'TEA', 'MILK'],
#  ['BREAD', 'BISCUIT', 'TEA', 'MAGGI'],
#  ['BREAD', 'BISCUIT', 'TEA', 'BOURNVITA'],
#  ['BREAD', 'BISCUIT', 'TEA', 'COKE'],
#  ['BREAD', 'BISCUIT', 'TEA', 'JAM'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'MILK'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'MAGGI'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'COKE'],
#  ['BREAD', 'BISCUIT', 'SUGER', 'JAM'],
#  ['BREAD', 'BISCUIT', 'CORNFLAKES', 'MILK'],
#  ['BREAD', 'BISCUIT', 'CORNFLAKES', 'MAGGI'],
#  ['BREAD', 'BISCUIT', 'CORNFLAKES', 'BOURNVITA'],
#  ['BREAD', 'BISCUIT', 'CORNFLAKES', 'COKE'],
#  ['BREAD', 'BISCUIT', 'CORNFLAKES', 'JAM'],
#  ['BREAD', 'BISCUIT', 'MILK', 'MAGGI'],
#  ['BREAD', 'BISCUIT', 'MILK', 'BOURNVITA'],
#  ['BREAD', 'BISCUIT', 'MILK', 'COKE'],
#  ['BREAD', 'BISCUIT', 'MILK', 'JAM'],
#  ['BREAD', 'BISCUIT', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'BISCUIT', 'MAGGI', 'COKE'],
#  ['BREAD', 'BISCUIT', 'MAGGI', 'JAM'],
#  ['BREAD', 'BISCUIT', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'BISCUIT', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'BISCUIT', 'COKE', 'JAM'],
#  ['BREAD', 'TEA', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'SUGER', 'MILK'],
#  ['BREAD', 'TEA', 'SUGER', 'MAGGI'],
#  ['BREAD', 'TEA', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'TEA', 'SUGER', 'COKE'],
#  ['BREAD', 'TEA', 'SUGER', 'JAM'],
#  ['BREAD', 'TEA', 'CORNFLAKES', 'MILK'],
#  ['BREAD', 'TEA', 'CORNFLAKES', 'MAGGI'],
#  ['BREAD', 'TEA', 'CORNFLAKES', 'BOURNVITA'],
#  ['BREAD', 'TEA', 'CORNFLAKES', 'COKE'],
#  ['BREAD', 'TEA', 'CORNFLAKES', 'JAM'],
#  ['BREAD', 'TEA', 'MILK', 'MAGGI'],
#  ['BREAD', 'TEA', 'MILK', 'BOURNVITA'],
#  ['BREAD', 'TEA', 'MILK', 'COKE'],
#  ['BREAD', 'TEA', 'MILK', 'JAM'],
#  ['BREAD', 'TEA', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'TEA', 'MAGGI', 'COKE'],
#  ['BREAD', 'TEA', 'MAGGI', 'JAM'],
#  ['BREAD', 'TEA', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'TEA', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'TEA', 'COKE', 'JAM'],
#  ['BREAD', 'SUGER', 'CORNFLAKES', 'MILK'],
#  ['BREAD', 'SUGER', 'CORNFLAKES', 'MAGGI'],
#  ['BREAD', 'SUGER', 'CORNFLAKES', 'BOURNVITA'],
#  ['BREAD', 'SUGER', 'CORNFLAKES', 'COKE'],
#  ['BREAD', 'SUGER', 'CORNFLAKES', 'JAM'],
#  ['BREAD', 'SUGER', 'MILK', 'MAGGI'],
#  ['BREAD', 'SUGER', 'MILK', 'BOURNVITA'],
#  ['BREAD', 'SUGER', 'MILK', 'COKE'],
#  ['BREAD', 'SUGER', 'MILK', 'JAM'],
#  ['BREAD', 'SUGER', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'SUGER', 'MAGGI', 'COKE'],
#  ['BREAD', 'SUGER', 'MAGGI', 'JAM'],
#  ['BREAD', 'SUGER', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'SUGER', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'SUGER', 'COKE', 'JAM'],
#  ['BREAD', 'CORNFLAKES', 'MILK', 'MAGGI'],
#  ['BREAD', 'CORNFLAKES', 'MILK', 'BOURNVITA'],
#  ['BREAD', 'CORNFLAKES', 'MILK', 'COKE'],
#  ['BREAD', 'CORNFLAKES', 'MILK', 'JAM'],
#  ['BREAD', 'CORNFLAKES', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'CORNFLAKES', 'MAGGI', 'COKE'],
#  ['BREAD', 'CORNFLAKES', 'MAGGI', 'JAM'],
#  ['BREAD', 'CORNFLAKES', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'CORNFLAKES', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'CORNFLAKES', 'COKE', 'JAM'],
#  ['BREAD', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['BREAD', 'MILK', 'MAGGI', 'COKE'],
#  ['BREAD', 'MILK', 'MAGGI', 'JAM'],
#  ['BREAD', 'MILK', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'MILK', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'MILK', 'COKE', 'JAM'],
#  ['BREAD', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['BREAD', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['BREAD', 'MAGGI', 'COKE', 'JAM'],
#  ['BREAD', 'BOURNVITA', 'COKE', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'SUGER'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'CORNFLAKES'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'MILK'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'MAGGI'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'BOURNVITA'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'TEA', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'CORNFLAKES'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'MILK'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'MAGGI'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'BOURNVITA'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'SUGER', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'CORNFLAKES', 'MILK'],
#  ['COFFEE', 'BISCUIT', 'CORNFLAKES', 'MAGGI'],
#  ['COFFEE', 'BISCUIT', 'CORNFLAKES', 'BOURNVITA'],
#  ['COFFEE', 'BISCUIT', 'CORNFLAKES', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'CORNFLAKES', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'MILK', 'MAGGI'],
#  ['COFFEE', 'BISCUIT', 'MILK', 'BOURNVITA'],
#  ['COFFEE', 'BISCUIT', 'MILK', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'MILK', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'MAGGI', 'BOURNVITA'],
#  ['COFFEE', 'BISCUIT', 'MAGGI', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'MAGGI', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'BISCUIT', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'BISCUIT', 'COKE', 'JAM'],
#  ['COFFEE', 'TEA', 'SUGER', 'CORNFLAKES'],
#  ['COFFEE', 'TEA', 'SUGER', 'MILK'],
#  ['COFFEE', 'TEA', 'SUGER', 'MAGGI'],
#  ['COFFEE', 'TEA', 'SUGER', 'BOURNVITA'],
#  ['COFFEE', 'TEA', 'SUGER', 'COKE'],
#  ['COFFEE', 'TEA', 'SUGER', 'JAM'],
#  ['COFFEE', 'TEA', 'CORNFLAKES', 'MILK'],
#  ['COFFEE', 'TEA', 'CORNFLAKES', 'MAGGI'],
#  ['COFFEE', 'TEA', 'CORNFLAKES', 'BOURNVITA'],
#  ['COFFEE', 'TEA', 'CORNFLAKES', 'COKE'],
#  ['COFFEE', 'TEA', 'CORNFLAKES', 'JAM'],
#  ['COFFEE', 'TEA', 'MILK', 'MAGGI'],
#  ['COFFEE', 'TEA', 'MILK', 'BOURNVITA'],
#  ['COFFEE', 'TEA', 'MILK', 'COKE'],
#  ['COFFEE', 'TEA', 'MILK', 'JAM'],
#  ['COFFEE', 'TEA', 'MAGGI', 'BOURNVITA'],
#  ['COFFEE', 'TEA', 'MAGGI', 'COKE'],
#  ['COFFEE', 'TEA', 'MAGGI', 'JAM'],
#  ['COFFEE', 'TEA', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'TEA', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'TEA', 'COKE', 'JAM'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES', 'MILK'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES', 'MAGGI'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES', 'BOURNVITA'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES', 'COKE'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES', 'JAM'],
#  ['COFFEE', 'SUGER', 'MILK', 'MAGGI'],
#  ['COFFEE', 'SUGER', 'MILK', 'BOURNVITA'],
#  ['COFFEE', 'SUGER', 'MILK', 'COKE'],
#  ['COFFEE', 'SUGER', 'MILK', 'JAM'],
#  ['COFFEE', 'SUGER', 'MAGGI', 'BOURNVITA'],
#  ['COFFEE', 'SUGER', 'MAGGI', 'COKE'],
#  ['COFFEE', 'SUGER', 'MAGGI', 'JAM'],
#  ['COFFEE', 'SUGER', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'SUGER', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'SUGER', 'COKE', 'JAM'],
#  ['COFFEE', 'CORNFLAKES', 'MILK', 'MAGGI'],
#  ['COFFEE', 'CORNFLAKES', 'MILK', 'BOURNVITA'],
#  ['COFFEE', 'CORNFLAKES', 'MILK', 'COKE'],
#  ['COFFEE', 'CORNFLAKES', 'MILK', 'JAM'],
#  ['COFFEE', 'CORNFLAKES', 'MAGGI', 'BOURNVITA'],
#  ['COFFEE', 'CORNFLAKES', 'MAGGI', 'COKE'],
#  ['COFFEE', 'CORNFLAKES', 'MAGGI', 'JAM'],
#  ['COFFEE', 'CORNFLAKES', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'CORNFLAKES', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'CORNFLAKES', 'COKE', 'JAM'],
#  ['COFFEE', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['COFFEE', 'MILK', 'MAGGI', 'COKE'],
#  ['COFFEE', 'MILK', 'MAGGI', 'JAM'],
#  ['COFFEE', 'MILK', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'MILK', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'MILK', 'COKE', 'JAM'],
#  ['COFFEE', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['COFFEE', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['COFFEE', 'MAGGI', 'COKE', 'JAM'],
#  ['COFFEE', 'BOURNVITA', 'COKE', 'JAM'],
#  ['BISCUIT', 'TEA', 'SUGER', 'CORNFLAKES'],
#  ['BISCUIT', 'TEA', 'SUGER', 'MILK'],
#  ['BISCUIT', 'TEA', 'SUGER', 'MAGGI'],
#  ['BISCUIT', 'TEA', 'SUGER', 'BOURNVITA'],
#  ['BISCUIT', 'TEA', 'SUGER', 'COKE'],
#  ['BISCUIT', 'TEA', 'SUGER', 'JAM'],
#  ['BISCUIT', 'TEA', 'CORNFLAKES', 'MILK'],
#  ['BISCUIT', 'TEA', 'CORNFLAKES', 'MAGGI'],
#  ['BISCUIT', 'TEA', 'CORNFLAKES', 'BOURNVITA'],
#  ['BISCUIT', 'TEA', 'CORNFLAKES', 'COKE'],
#  ['BISCUIT', 'TEA', 'CORNFLAKES', 'JAM'],
#  ['BISCUIT', 'TEA', 'MILK', 'MAGGI'],
#  ['BISCUIT', 'TEA', 'MILK', 'BOURNVITA'],
#  ['BISCUIT', 'TEA', 'MILK', 'COKE'],
#  ['BISCUIT', 'TEA', 'MILK', 'JAM'],
#  ['BISCUIT', 'TEA', 'MAGGI', 'BOURNVITA'],
#  ['BISCUIT', 'TEA', 'MAGGI', 'COKE'],
#  ['BISCUIT', 'TEA', 'MAGGI', 'JAM'],
#  ['BISCUIT', 'TEA', 'BOURNVITA', 'COKE'],
#  ['BISCUIT', 'TEA', 'BOURNVITA', 'JAM'],
#  ['BISCUIT', 'TEA', 'COKE', 'JAM'],
#  ['BISCUIT', 'SUGER', 'CORNFLAKES', 'MILK'],
#  ['BISCUIT', 'SUGER', 'CORNFLAKES', 'MAGGI'],
#  ['BISCUIT', 'SUGER', 'CORNFLAKES', 'BOURNVITA'],
#  ['BISCUIT', 'SUGER', 'CORNFLAKES', 'COKE'],
#  ['BISCUIT', 'SUGER', 'CORNFLAKES', 'JAM'],
#  ['BISCUIT', 'SUGER', 'MILK', 'MAGGI'],
#  ['BISCUIT', 'SUGER', 'MILK', 'BOURNVITA'],
#  ['BISCUIT', 'SUGER', 'MILK', 'COKE'],
#  ['BISCUIT', 'SUGER', 'MILK', 'JAM'],
#  ['BISCUIT', 'SUGER', 'MAGGI', 'BOURNVITA'],
#  ['BISCUIT', 'SUGER', 'MAGGI', 'COKE'],
#  ['BISCUIT', 'SUGER', 'MAGGI', 'JAM'],
#  ['BISCUIT', 'SUGER', 'BOURNVITA', 'COKE'],
#  ['BISCUIT', 'SUGER', 'BOURNVITA', 'JAM'],
#  ['BISCUIT', 'SUGER', 'COKE', 'JAM'],
#  ['BISCUIT', 'CORNFLAKES', 'MILK', 'MAGGI'],
#  ['BISCUIT', 'CORNFLAKES', 'MILK', 'BOURNVITA'],
#  ['BISCUIT', 'CORNFLAKES', 'MILK', 'COKE'],
#  ['BISCUIT', 'CORNFLAKES', 'MILK', 'JAM'],
#  ['BISCUIT', 'CORNFLAKES', 'MAGGI', 'BOURNVITA'],
#  ['BISCUIT', 'CORNFLAKES', 'MAGGI', 'COKE'],
#  ['BISCUIT', 'CORNFLAKES', 'MAGGI', 'JAM'],
#  ['BISCUIT', 'CORNFLAKES', 'BOURNVITA', 'COKE'],
#  ['BISCUIT', 'CORNFLAKES', 'BOURNVITA', 'JAM'],
#  ['BISCUIT', 'CORNFLAKES', 'COKE', 'JAM'],
#  ['BISCUIT', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['BISCUIT', 'MILK', 'MAGGI', 'COKE'],
#  ['BISCUIT', 'MILK', 'MAGGI', 'JAM'],
#  ['BISCUIT', 'MILK', 'BOURNVITA', 'COKE'],
#  ['BISCUIT', 'MILK', 'BOURNVITA', 'JAM'],
#  ['BISCUIT', 'MILK', 'COKE', 'JAM'],
#  ['BISCUIT', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['BISCUIT', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['BISCUIT', 'MAGGI', 'COKE', 'JAM'],
#  ['BISCUIT', 'BOURNVITA', 'COKE', 'JAM'],
#  ['TEA', 'SUGER', 'CORNFLAKES', 'MILK'],
#  ['TEA', 'SUGER', 'CORNFLAKES', 'MAGGI'],
#  ['TEA', 'SUGER', 'CORNFLAKES', 'BOURNVITA'],
#  ['TEA', 'SUGER', 'CORNFLAKES', 'COKE'],
#  ['TEA', 'SUGER', 'CORNFLAKES', 'JAM'],
#  ['TEA', 'SUGER', 'MILK', 'MAGGI'],
#  ['TEA', 'SUGER', 'MILK', 'BOURNVITA'],
#  ['TEA', 'SUGER', 'MILK', 'COKE'],
#  ['TEA', 'SUGER', 'MILK', 'JAM'],
#  ['TEA', 'SUGER', 'MAGGI', 'BOURNVITA'],
#  ['TEA', 'SUGER', 'MAGGI', 'COKE'],
#  ['TEA', 'SUGER', 'MAGGI', 'JAM'],
#  ['TEA', 'SUGER', 'BOURNVITA', 'COKE'],
#  ['TEA', 'SUGER', 'BOURNVITA', 'JAM'],
#  ['TEA', 'SUGER', 'COKE', 'JAM'],
#  ['TEA', 'CORNFLAKES', 'MILK', 'MAGGI'],
#  ['TEA', 'CORNFLAKES', 'MILK', 'BOURNVITA'],
#  ['TEA', 'CORNFLAKES', 'MILK', 'COKE'],
#  ['TEA', 'CORNFLAKES', 'MILK', 'JAM'],
#  ['TEA', 'CORNFLAKES', 'MAGGI', 'BOURNVITA'],
#  ['TEA', 'CORNFLAKES', 'MAGGI', 'COKE'],
#  ['TEA', 'CORNFLAKES', 'MAGGI', 'JAM'],
#  ['TEA', 'CORNFLAKES', 'BOURNVITA', 'COKE'],
#  ['TEA', 'CORNFLAKES', 'BOURNVITA', 'JAM'],
#  ['TEA', 'CORNFLAKES', 'COKE', 'JAM'],
#  ['TEA', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['TEA', 'MILK', 'MAGGI', 'COKE'],
#  ['TEA', 'MILK', 'MAGGI', 'JAM'],
#  ['TEA', 'MILK', 'BOURNVITA', 'COKE'],
#  ['TEA', 'MILK', 'BOURNVITA', 'JAM'],
#  ['TEA', 'MILK', 'COKE', 'JAM'],
#  ['TEA', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['TEA', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['TEA', 'MAGGI', 'COKE', 'JAM'],
#  ['TEA', 'BOURNVITA', 'COKE', 'JAM'],
#  ['SUGER', 'CORNFLAKES', 'MILK', 'MAGGI'],
#  ['SUGER', 'CORNFLAKES', 'MILK', 'BOURNVITA'],
#  ['SUGER', 'CORNFLAKES', 'MILK', 'COKE'],
#  ['SUGER', 'CORNFLAKES', 'MILK', 'JAM'],
#  ['SUGER', 'CORNFLAKES', 'MAGGI', 'BOURNVITA'],
#  ['SUGER', 'CORNFLAKES', 'MAGGI', 'COKE'],
#  ['SUGER', 'CORNFLAKES', 'MAGGI', 'JAM'],
#  ['SUGER', 'CORNFLAKES', 'BOURNVITA', 'COKE'],
#  ['SUGER', 'CORNFLAKES', 'BOURNVITA', 'JAM'],
#  ['SUGER', 'CORNFLAKES', 'COKE', 'JAM'],
#  ['SUGER', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['SUGER', 'MILK', 'MAGGI', 'COKE'],
#  ['SUGER', 'MILK', 'MAGGI', 'JAM'],
#  ['SUGER', 'MILK', 'BOURNVITA', 'COKE'],
#  ['SUGER', 'MILK', 'BOURNVITA', 'JAM'],
#  ['SUGER', 'MILK', 'COKE', 'JAM'],
#  ['SUGER', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['SUGER', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['SUGER', 'MAGGI', 'COKE', 'JAM'],
#  ['SUGER', 'BOURNVITA', 'COKE', 'JAM'],
#  ['CORNFLAKES', 'MILK', 'MAGGI', 'BOURNVITA'],
#  ['CORNFLAKES', 'MILK', 'MAGGI', 'COKE'],
#  ['CORNFLAKES', 'MILK', 'MAGGI', 'JAM'],
#  ['CORNFLAKES', 'MILK', 'BOURNVITA', 'COKE'],
#  ['CORNFLAKES', 'MILK', 'BOURNVITA', 'JAM'],
#  ['CORNFLAKES', 'MILK', 'COKE', 'JAM'],
#  ['CORNFLAKES', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['CORNFLAKES', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['CORNFLAKES', 'MAGGI', 'COKE', 'JAM'],
#  ['CORNFLAKES', 'BOURNVITA', 'COKE', 'JAM'],
#  ['MILK', 'MAGGI', 'BOURNVITA', 'COKE'],
#  ['MILK', 'MAGGI', 'BOURNVITA', 'JAM'],
#  ['MILK', 'MAGGI', 'COKE', 'JAM'],
#  ['MILK', 'BOURNVITA', 'COKE', 'JAM'],
#  ['MAGGI', 'BOURNVITA', 'COKE', 'JAM']]

# %%
from mlxtend.frequent_patterns import apriori

# %%
df1 = apriori(df,min_support=0.001,use_colnames=True)
df1
# Out:
#     support                                        itemsets
# 0      0.35                            frozenset({BISCUIT})
# 1      0.20                          frozenset({BOURNVITA})
# 2      0.65                              frozenset({BREAD})
# 3      0.40                             frozenset({COFFEE})
# 4      0.15                               frozenset({COKE})
# ..      ...                                             ...
# 78     0.05         frozenset({TEA, MAGGI, BISCUIT, BREAD})
# 79     0.10  frozenset({COKE, COFFEE, BISCUIT, CORNFLAKES})
# 80     0.05            frozenset({JAM, MILK, MAGGI, BREAD})
# 81     0.05             frozenset({JAM, TEA, MAGGI, BREAD})
# 82     0.05      frozenset({COFFEE, TEA, MILK, CORNFLAKES})
#
# [83 rows x 2 columns]

# %%
df1.head(20).sort_values(by="support",ascending=False)
# Out:
#     support                          itemsets
# 2      0.65                frozenset({BREAD})
# 3      0.40               frozenset({COFFEE})
# 0      0.35              frozenset({BISCUIT})
# 10     0.35                  frozenset({TEA})
# 9      0.30                frozenset({SUGER})
# 5      0.30           frozenset({CORNFLAKES})
# 8      0.25                 frozenset({MILK})
# 7      0.25                frozenset({MAGGI})
# 1      0.20            frozenset({BOURNVITA})
# 11     0.20       frozenset({BISCUIT, BREAD})
# 4      0.15                 frozenset({COKE})
# 14     0.15  frozenset({CORNFLAKES, BISCUIT})
# 19     0.15     frozenset({BOURNVITA, BREAD})
# 6      0.10                  frozenset({JAM})
# 13     0.10        frozenset({COKE, BISCUIT})
# 12     0.10      frozenset({COFFEE, BISCUIT})
# 15     0.10       frozenset({MAGGI, BISCUIT})
# 16     0.10        frozenset({MILK, BISCUIT})
# 18     0.10         frozenset({TEA, BISCUIT})
# 17     0.05       frozenset({SUGER, BISCUIT})

# %%
df1['length'] = df1['itemsets'].apply(lambda x:len(x))
df1
# Out:
#     support                                        itemsets  length
# 0      0.35                            frozenset({BISCUIT})       1
# 1      0.20                          frozenset({BOURNVITA})       1
# 2      0.65                              frozenset({BREAD})       1
# 3      0.40                             frozenset({COFFEE})       1
# 4      0.15                               frozenset({COKE})       1
# ..      ...                                             ...     ...
# 78     0.05         frozenset({TEA, MAGGI, BISCUIT, BREAD})       4
# 79     0.10  frozenset({COKE, COFFEE, BISCUIT, CORNFLAKES})       4
# 80     0.05            frozenset({JAM, MILK, MAGGI, BREAD})       4
# 81     0.05             frozenset({JAM, TEA, MAGGI, BREAD})       4
# 82     0.05      frozenset({COFFEE, TEA, MILK, CORNFLAKES})       4
#
# [83 rows x 3 columns]

# %%
df1[(df1['length']==2) & (df1['support']>=0.05)]
# Out:
#     support                          itemsets  length
# 11     0.20       frozenset({BISCUIT, BREAD})       2
# 12     0.10      frozenset({COFFEE, BISCUIT})       2
# 13     0.10        frozenset({COKE, BISCUIT})       2
# 14     0.15  frozenset({CORNFLAKES, BISCUIT})       2
# 15     0.10       frozenset({MAGGI, BISCUIT})       2
# 16     0.10        frozenset({MILK, BISCUIT})       2
# 17     0.05       frozenset({SUGER, BISCUIT})       2
# 18     0.10         frozenset({TEA, BISCUIT})       2
# 19     0.15     frozenset({BOURNVITA, BREAD})       2
# 20     0.05    frozenset({COFFEE, BOURNVITA})       2
# 21     0.10     frozenset({SUGER, BOURNVITA})       2
# 22     0.10       frozenset({TEA, BOURNVITA})       2
# 23     0.15        frozenset({COFFEE, BREAD})       2
# 24     0.05          frozenset({COKE, BREAD})       2
# 25     0.05    frozenset({CORNFLAKES, BREAD})       2
# 26     0.10           frozenset({JAM, BREAD})       2
# 27     0.15         frozenset({MAGGI, BREAD})       2
# 28     0.20          frozenset({MILK, BREAD})       2
# 29     0.20         frozenset({SUGER, BREAD})       2
# 30     0.20           frozenset({TEA, BREAD})       2
# 31     0.15         frozenset({COKE, COFFEE})       2
# 32     0.20   frozenset({CORNFLAKES, COFFEE})       2
# 33     0.05         frozenset({COFFEE, MILK})       2
# 34     0.20        frozenset({SUGER, COFFEE})       2
# 35     0.05          frozenset({TEA, COFFEE})       2
# 36     0.10     frozenset({COKE, CORNFLAKES})       2
# 37     0.05    frozenset({CORNFLAKES, MAGGI})       2
# 38     0.10     frozenset({CORNFLAKES, MILK})       2
# 39     0.05    frozenset({SUGER, CORNFLAKES})       2
# 40     0.10      frozenset({TEA, CORNFLAKES})       2
# 41     0.10           frozenset({JAM, MAGGI})       2
# 42     0.05            frozenset({JAM, MILK})       2
# 43     0.05             frozenset({JAM, TEA})       2
# 44     0.05          frozenset({MILK, MAGGI})       2
# 45     0.20           frozenset({TEA, MAGGI})       2
# 46     0.05            frozenset({TEA, MILK})       2

# %%
from mlxtend.frequent_patterns import association_rules

# %%
# Association Rules & Info
df_ar = association_rules(df1, metric = "confidence", min_threshold = 0.2)
df_ar
# Out:
#                          antecedents                           consequents  \
# 0               frozenset({BISCUIT})                    frozenset({BREAD})
# 1                 frozenset({BREAD})                  frozenset({BISCUIT})
# 2                frozenset({COFFEE})                  frozenset({BISCUIT})
# 3               frozenset({BISCUIT})                   frozenset({COFFEE})
# 4                  frozenset({COKE})                  frozenset({BISCUIT})
# ..                               ...                                   ...
# 259     frozenset({TEA, CORNFLAKES})             frozenset({COFFEE, MILK})
# 260        frozenset({COFFEE, MILK})          frozenset({TEA, CORNFLAKES})
# 261  frozenset({CORNFLAKES, COFFEE})                frozenset({TEA, MILK})
# 262    frozenset({CORNFLAKES, MILK})              frozenset({TEA, COFFEE})
# 263                frozenset({MILK})  frozenset({TEA, COFFEE, CORNFLAKES})
#
#      antecedent support  consequent support  support  confidence       lift  \
# 0                  0.35                0.65     0.20    0.571429   0.879121
# 1                  0.65                0.35     0.20    0.307692   0.879121
# 2                  0.40                0.35     0.10    0.250000   0.714286
# 3                  0.35                0.40     0.10    0.285714   0.714286
# 4                  0.15                0.35     0.10    0.666667   1.904762
# ..                  ...                 ...      ...         ...        ...
# 259                0.10                0.05     0.05    0.500000  10.000000
# 260                0.05                0.10     0.05    1.000000  10.000000
# 261                0.20                0.05     0.05    0.250000   5.000000
# 262                0.10                0.05     0.05    0.500000  10.000000
# 263                0.25                0.05     0.05    0.200000   4.000000
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                 1.0   -0.0275    0.816667      -0.174603  0.250000
# 1                 1.0   -0.0275    0.938889      -0.282051  0.250000
# 2                 1.0   -0.0400    0.866667      -0.400000  0.153846
# 3                 1.0   -0.0400    0.840000      -0.380952  0.153846
# 4                 1.0    0.0475    1.950000       0.558824  0.250000
# ..                ...       ...         ...            ...       ...
# 259               1.0    0.0450    1.900000       1.000000  0.500000
# 260               1.0    0.0450         inf       0.947368  0.500000
# 261               1.0    0.0400    1.266667       1.000000  0.250000
# 262               1.0    0.0450    1.900000       1.000000  0.500000
# 263               1.0    0.0375    1.187500       1.000000  0.200000
#
#      certainty  kulczynski
# 0    -0.224490    0.439560
# 1    -0.065089    0.439560
# 2    -0.153846    0.267857
# 3    -0.190476    0.267857
# 4     0.487179    0.476190
# ..         ...         ...
# 259   0.473684    0.750000
# 260   1.000000    0.750000
# 261   0.210526    0.625000
# 262   0.473684    0.750000
# 263   0.157895    0.600000
#
# [264 rows x 14 columns]

# %% [markdown]
# * Antecedent support variable tells us probability of antecedent products alone
# * Consequents support variable tells us probability of consequents products alone
# * The support value is the value of the two products (Antecedents and Consequents)
# * Confidence is an indication of how often the rule has been found to be true.
# * The ratio of the observed support to that expected if X and Y were independent.

# %% [markdown]
# **Lift indicates:**
#
# 1. Whether if two type of products can be sold together - lift value higher than 1
# 2. Whether 1 product be substitute of other - lift value lower than 1
# 3. Whether if there is no relation between the type or products - lift value equals to 1

# %%
df_ar[(df_ar.support >0.15) & (df_ar.confidence > 0.70) & (df_ar.lift > 1.0)].sort_values("confidence", ascending = False)
# Out:
#            antecedents         consequents  antecedent support  \
# 27   frozenset({MILK})  frozenset({BREAD})                0.25
# 55  frozenset({MAGGI})    frozenset({TEA})                0.25
#
#     consequent support  support  confidence      lift  representativity  \
# 27                0.65      0.2         0.8  1.230769               1.0
# 55                0.35      0.2         0.8  2.285714               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 27    0.0375        1.75           0.25  0.285714   0.428571    0.553846
# 55    0.1125        3.25           0.75  0.500000   0.692308    0.685714

# %% [markdown]
# **For MILK-BREAD pair:** antecedent support=0.25: Milk is observed in 25% of all the purchases. consequent support=0.65: Bread is observed 65% of all the purchases. support=0.20 : Milk and Bread are observed together in 20% of all purchases. confidence=0.8: If Milk is bought, Bread is 80% likely to be bought as well. Lift=1.23: That means Milk and Bread affects each other's sales positively. Sales of Bread increase by 1.23 times in transactions which contains Milk or visa versa.
#
# **For MAGGI-TEA pair:** antecedent support=0.25: Maggi is observed in 25% of all the purchases. consequent support=0.35: Tea is observed 35% of all the purchases. support=0.20 : Maggi and Tea are observed together in 20% of all purchases. confidence=0.8: If Maggi is bought, Tea is 80% likely to be bought as well. Lift=2.286: That means Maggi and Tea affects each other's sales positively. Sales of Maggi increase by 2.286 times in transactions which contains Tea or visa versa.

# %%
df_lift = association_rules(df1, metric = 'lift', min_threshold = 5) 
# displaying results with lift >= 1
df_lift.sort_values(by = 'lift', ascending = False)
# Out:
#                                  antecedents  \
# 4                   frozenset({MILK, MAGGI})
# 5                           frozenset({JAM})
# 10             frozenset({COKE, CORNFLAKES})
# 11              frozenset({COFFEE, BISCUIT})
# 7                 frozenset({MILK, BISCUIT})
# 6             frozenset({CORNFLAKES, BREAD})
# 24                  frozenset({TEA, COFFEE})
# 29             frozenset({CORNFLAKES, MILK})
# 27                 frozenset({COFFEE, MILK})
# 26              frozenset({TEA, CORNFLAKES})
# 19                          frozenset({JAM})
# 17                  frozenset({MILK, MAGGI})
# 16                   frozenset({JAM, BREAD})
# 14           frozenset({MILK, MAGGI, BREAD})
# 22                 frozenset({MAGGI, BREAD})
# 21                     frozenset({JAM, TEA})
# 8   frozenset({CORNFLAKES, COFFEE, BISCUIT})
# 13                         frozenset({COKE})
# 1                          frozenset({COKE})
# 0               frozenset({COFFEE, BISCUIT})
# 3                           frozenset({JAM})
# 2                  frozenset({MAGGI, BREAD})
# 18                 frozenset({MAGGI, BREAD})
# 15                    frozenset({JAM, MILK})
# 12           frozenset({CORNFLAKES, COFFEE})
# 9                 frozenset({COKE, BISCUIT})
# 20            frozenset({TEA, MAGGI, BREAD})
# 23                          frozenset({JAM})
# 25                    frozenset({TEA, MILK})
# 28           frozenset({CORNFLAKES, COFFEE})
#
#                                  consequents  antecedent support  \
# 4                           frozenset({JAM})                0.05
# 5                   frozenset({MILK, MAGGI})                0.10
# 10              frozenset({COFFEE, BISCUIT})                0.10
# 11             frozenset({COKE, CORNFLAKES})                0.10
# 7             frozenset({CORNFLAKES, BREAD})                0.10
# 6                 frozenset({MILK, BISCUIT})                0.05
# 24             frozenset({CORNFLAKES, MILK})                0.05
# 29                  frozenset({TEA, COFFEE})                0.10
# 27              frozenset({TEA, CORNFLAKES})                0.05
# 26                 frozenset({COFFEE, MILK})                0.10
# 19           frozenset({MILK, MAGGI, BREAD})                0.10
# 17                   frozenset({JAM, BREAD})                0.05
# 16                  frozenset({MILK, MAGGI})                0.10
# 14                          frozenset({JAM})                0.05
# 22                     frozenset({JAM, TEA})                0.15
# 21                 frozenset({MAGGI, BREAD})                0.05
# 8                          frozenset({COKE})                0.10
# 13  frozenset({CORNFLAKES, COFFEE, BISCUIT})                0.15
# 1               frozenset({COFFEE, BISCUIT})                0.15
# 0                          frozenset({COKE})                0.10
# 3                  frozenset({MAGGI, BREAD})                0.10
# 2                           frozenset({JAM})                0.15
# 18                    frozenset({JAM, MILK})                0.15
# 15                 frozenset({MAGGI, BREAD})                0.05
# 12                frozenset({COKE, BISCUIT})                0.20
# 9            frozenset({CORNFLAKES, COFFEE})                0.10
# 20                          frozenset({JAM})                0.10
# 23            frozenset({TEA, MAGGI, BREAD})                0.10
# 25           frozenset({CORNFLAKES, COFFEE})                0.05
# 28                    frozenset({TEA, MILK})                0.20
#
#     consequent support  support  confidence       lift  representativity  \
# 4                 0.10     0.05    1.000000  10.000000               1.0
# 5                 0.05     0.05    0.500000  10.000000               1.0
# 10                0.10     0.10    1.000000  10.000000               1.0
# 11                0.10     0.10    1.000000  10.000000               1.0
# 7                 0.05     0.05    0.500000  10.000000               1.0
# 6                 0.10     0.05    1.000000  10.000000               1.0
# 24                0.10     0.05    1.000000  10.000000               1.0
# 29                0.05     0.05    0.500000  10.000000               1.0
# 27                0.10     0.05    1.000000  10.000000               1.0
# 26                0.05     0.05    0.500000  10.000000               1.0
# 19                0.05     0.05    0.500000  10.000000               1.0
# 17                0.10     0.05    1.000000  10.000000               1.0
# 16                0.05     0.05    0.500000  10.000000               1.0
# 14                0.10     0.05    1.000000  10.000000               1.0
# 22                0.05     0.05    0.333333   6.666667               1.0
# 21                0.15     0.05    1.000000   6.666667               1.0
# 8                 0.15     0.10    1.000000   6.666667               1.0
# 13                0.10     0.10    0.666667   6.666667               1.0
# 1                 0.10     0.10    0.666667   6.666667               1.0
# 0                 0.15     0.10    1.000000   6.666667               1.0
# 3                 0.15     0.10    1.000000   6.666667               1.0
# 2                 0.10     0.10    0.666667   6.666667               1.0
# 18                0.05     0.05    0.333333   6.666667               1.0
# 15                0.15     0.05    1.000000   6.666667               1.0
# 12                0.10     0.10    0.500000   5.000000               1.0
# 9                 0.20     0.10    1.000000   5.000000               1.0
# 20                0.10     0.05    0.500000   5.000000               1.0
# 23                0.10     0.05    0.500000   5.000000               1.0
# 25                0.20     0.05    1.000000   5.000000               1.0
# 28                0.05     0.05    0.250000   5.000000               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 4     0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 5     0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 10    0.0900         inf       1.000000  1.000000   1.000000    1.000000
# 11    0.0900         inf       1.000000  1.000000   1.000000    1.000000
# 7     0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 6     0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 24    0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 29    0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 27    0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 26    0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 19    0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 17    0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 16    0.0450    1.900000       1.000000  0.500000   0.473684    0.750000
# 14    0.0450         inf       0.947368  0.500000   1.000000    0.750000
# 22    0.0425    1.425000       1.000000  0.333333   0.298246    0.666667
# 21    0.0425         inf       0.894737  0.333333   1.000000    0.666667
# 8     0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 13    0.0850    2.700000       1.000000  0.666667   0.629630    0.833333
# 1     0.0850    2.700000       1.000000  0.666667   0.629630    0.833333
# 0     0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 3     0.0850         inf       0.944444  0.666667   1.000000    0.833333
# 2     0.0850    2.700000       1.000000  0.666667   0.629630    0.833333
# 18    0.0425    1.425000       1.000000  0.333333   0.298246    0.666667
# 15    0.0425         inf       0.894737  0.333333   1.000000    0.666667
# 12    0.0800    1.800000       1.000000  0.500000   0.444444    0.750000
# 9     0.0800         inf       0.888889  0.500000   1.000000    0.750000
# 20    0.0400    1.800000       0.888889  0.333333   0.444444    0.500000
# 23    0.0400    1.800000       0.888889  0.333333   0.444444    0.500000
# 25    0.0400         inf       0.842105  0.250000   1.000000    0.625000
# 28    0.0400    1.266667       1.000000  0.250000   0.210526    0.625000

# %%
df_lift = association_rules(df1, metric = 'lift', min_threshold = 0) # displaying results with lift >= 0
df_lift[df_lift['lift'] == 1]
# Out:
#                          antecedents                      consequents  \
# 80       frozenset({BISCUIT, BREAD})               frozenset({MAGGI})
# 81                frozenset({MAGGI})      frozenset({BISCUIT, BREAD})
# 187         frozenset({MILK, BREAD})               frozenset({MAGGI})
# 190               frozenset({MAGGI})         frozenset({MILK, BREAD})
# 204  frozenset({CORNFLAKES, COFFEE})                frozenset({MILK})
# 209                frozenset({MILK})  frozenset({CORNFLAKES, COFFEE})
#
#      antecedent support  consequent support  support  confidence  lift  \
# 80                 0.20                0.25     0.05        0.25   1.0
# 81                 0.25                0.20     0.05        0.20   1.0
# 187                0.20                0.25     0.05        0.25   1.0
# 190                0.25                0.20     0.05        0.20   1.0
# 204                0.20                0.25     0.05        0.25   1.0
# 209                0.25                0.20     0.05        0.20   1.0
#
#      representativity  leverage  conviction  zhangs_metric  jaccard  \
# 80                1.0       0.0         1.0            0.0    0.125
# 81                1.0       0.0         1.0            0.0    0.125
# 187               1.0       0.0         1.0            0.0    0.125
# 190               1.0       0.0         1.0            0.0    0.125
# 204               1.0       0.0         1.0            0.0    0.125
# 209               1.0       0.0         1.0            0.0    0.125
#
#      certainty  kulczynski
# 80         0.0       0.225
# 81         0.0       0.225
# 187        0.0       0.225
# 190        0.0       0.225
# 204        0.0       0.225
# 209        0.0       0.225
